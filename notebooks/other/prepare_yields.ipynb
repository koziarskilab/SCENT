# %%
import pandas as pd

df = pd.read_csv('rgfn_new_yields.csv')
df
# Out:
#                         Family  \
# 0             Carbocyclic SnAr
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ..                         ...
# 110                        NaN
# 111                        NaN
# 112  NH heterocycle alkylation
# 113                        NaN
# 114                        NaN
#
#                                               Reaction  \
# 0    [#6&!$(C=[O,N]):9][Nh2:1].[F]-[c:2]1[c:3][c:4]...
# 1    [#6&!$(C=[O,N]):9][Nh:1][#6&!$(C=[O,N]):20].[F...
# 2    [#6&!$(C=[O,N]):9][Nh:1][#6&!$(C=[O,N]):20].[F...
# 3    [#6&!$(C=[O,N]):9][Nh2:1].[F]-[c:2]1[c:3]([C:8...
# 4    [#6&!$(C=[O,N]):9][Nh:1]([#6&!$(C=[O,N]):20])....
# ..                                                 ...
# 110  [#6:1]-[C:2](=[O])-[C:3](-[Br])-[#6:4].[S:5]=[...
# 111  [#6:1]-[C:2](=[O])-[C:3](-[I])-[#6:4].[S:5]=[C...
# 112  [c:1][nH:2][c:3].[Cl]-[Ch2:4]-[#6:5]>>[c:1][n:...
# ...
