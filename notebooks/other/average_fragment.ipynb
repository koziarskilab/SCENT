# %%
import json

cost_dict = json.load(open('../../data/synflow/fragment_128k_to_real_cost_sanitized.json'))
# compute mean cost
mean_cost = sum(cost_dict.values()) / len(cost_dict)
mean_cost
# Out:
# 193.71240300902778
